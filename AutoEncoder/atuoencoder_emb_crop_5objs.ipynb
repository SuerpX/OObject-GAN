# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision as torchv
import numpy as np
import mymodels
import mycoco_emb_crop as mycoco
import torchvision.transforms as transforms
import torch.utils.data as data
from tensorboardX import SummaryWriter
import torchvision.utils as vutils
import os
import pdb
from models.model_embedding_128 import Embdding_128 as model_emb

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

import matplotlib.pyplot as plt
# %matplotlib inline

from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision.utils import save_image

# %%
print("Torch Version: {}".format(torch.__version__))
print("Cuda Available: {} \t device Count: {}".format(torch.cuda.is_available(), torch.cuda.device_count()))
# Out:
# Torch Version: 1.0.1.post2
# Cuda Available: True 	 device Count: 1

# %%
BATCH_SIZE = 64
cuda = torch.cuda.is_available()
IMAGE_SIZE = 224

# %%
datasets
# Out:
# <module 'torchvision.datasets' from '/nfs/stak/users/linzhe/miniconda3/envs/general/lib/python3.6/site-packages/torchvision/datasets/__init__.py'>

# %%
mycoco.CocoDetection?
# Out:
# Init signature:
# mycoco.CocoDetection(
#     root,
#     annFile,
#     transform=None,
#     target_transform=None,
#     categories=None,
#     batch_size=32,
# )
# Docstring:
# `MS Coco Detection <http://mscoco.org/dataset/#detections-challenge2016>`_ Dataset.
#
# Args:
#     root (string): Root directory where images are downloaded to.
#     annFile (string): Path to json annotation file.
#     transform (callable, optional): A function/transform that  takes in an PIL image
#         and returns a transformed version. E.g, ``transforms.ToTensor``
#     target_transform (callable, optional): A function/transform that takes in the
#         target and transforms it.
# File:           /nfs/eecs-fserv/share/linzhe/CS535Proj/TestExamples/AutoEncoder/mycoco_emb_crop.py
# Type:           type
# Subclasses:

# %%
def create_dataset(name='train', batch_size=32):
    dataDir='/scratch/cluster-share/linzhe/cocoDataset/'
    dataType='%s2017'%name
    annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)
    root = '%s%s'%(dataDir, dataType)

    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                         std=[0.229, 0.224, 0.225])
    trans = transforms.Compose([transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
                                transforms.ToTensor()])
    target_transform = transforms.Compose([transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
                                           transforms.ToTensor()
                                           ]) # normalize to be in [-1, 1]
    coco = mycoco.CocoDetection(root, annFile, transform=trans, target_transform=target_transform, categories=['horse', 'zebra', 'elephant', 'apple', 'orange'])
    cocoloader = data.DataLoader(coco, batch_size, num_workers=4, shuffle=True)
    
    return cocoloader, coco

# %%
cocoloader, cocoDataset = create_dataset(name='train', batch_size=BATCH_SIZE)
# Out:
# loading annotations into memory...
# Done (t=19.76s)
# creating index...
# index created!

# %%
# check that there exist 10 different classes
np.unique(cocoDataset.categories)
# Out:
# array(['apple', 'elephant', 'horse', 'orange', 'zebra'], dtype='<U8')

# %%
for im, mask in cocoloader:
    print(im.shape)
    print(np.swapaxes(np.swapaxes(im[0].numpy(),0,1),1,2).shape)
    break
    


f, axarr = plt.subplots(4, 4, figsize=(15, 15)) # Grid size of 10X10 and a fig size
f.subplots_adjust()
i = 0
j = 0
for im, mask in  cocoloader:
#     print(im.shape)
    for image in im:
#         print(image.numpy().T.shape)
        axarr[i, j].imshow(np.swapaxes(np.swapaxes(image.numpy(),0,1),1,2))
        axarr[i, j].axis('off')
        j+=1
        if(j%4==0):
            i+=1
        j=j%4
        
        if(i%4==0 and i>0):
            break
    break
# Out:
# torch.Size([64, 3, 224, 224])
# (224, 224, 3)

# %%
f, axarr = plt.subplots(4, 4, figsize=(15, 15)) # Grid size of 10X10 and a fig size
f.subplots_adjust()
i = 0
j = 0
for im, mask in  cocoloader:
    
    for image in mask:
        print(np.sum(image.numpy()[0]))
#         print(image.numpy()[0])
#         print(image.numpy()[0].shape)
        axarr[i, j].imshow(image.numpy()[0])
        axarr[i, j].axis('off')
        j+=1
        if(j%4==0):
            i+=1
        j=j%4
        
        if(i%4==0 and i>0):
            break
    break
# Out:
# 15236.985
# 14421.371
# 11558.65
# 22126.709
# 10742.67
# 19598.572
# 10997.486
# 21047.482
# 10649.491
# 14219.956
# 18685.639
# 21649.33
# 18534.96
# 15651.818
# 21076.791
# 24870.713

# %%
f, axarr = plt.subplots(4, 4, figsize=(15, 15)) # Grid size of 10X10 and a fig size
f.subplots_adjust()
i = 0
j = 0
for im, mask in  cocoloader:
    im = np.multiply(im,mask)
#     print(im.shape)
    for image in im:
#         print(image.numpy().T.shape)
        axarr[i, j].imshow(np.swapaxes(np.swapaxes(image.numpy(),0,1),1,2))
        axarr[i, j].axis('off')
        j+=1
        if(j%4==0):
            i+=1
        j=j%4
        
        if(i%4==0 and i>0):
            break
    break

# %%
data_loader = cocoloader
# pin_memory if you're on GPU

# %%
from torch import nn

# %%
n_batches = int(np.ceil(len(cocoDataset)/ BATCH_SIZE)) # 60000 / 100

# %%
n_batches
# Out:
# 69

# %%
#first model
#encoder: four conv layers 3-16-32-64-128-FC
#decoder: four deconv layers FC-128-64-32-16-3
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision as tv

class EmbeddingModel(nn.Module):
    def __init__(self, in_channels, embedding_size=128):
        super().__init__()
        rn = tv.models.resnet18()
        self.inp = nn.Conv2d(in_channels, 64, kernel_size=7, stride=2, padding=3, bias=False)
#         self.backbo
        self.backbone= nn.Sequential(*list(rn.children())[1:-2])
        self.out1 = nn.AdaptiveAvgPool2d(1)
                     
        self.out2 = nn.Linear(512, embedding_size)
    def forward(self, x):
        x = self.inp(x)
        x = self.backbone(x)
        x = self.out1(x).contiguous().view(x.shape[0],-1)
        x = F.tanh(self.out2(x))
        #print(x.shape)
        return x
#         print(rn(torch.))


class Decoder(nn.Module):
    def __init__(self, IMAGE_SIZE):

        super(Decoder, self).__init__()
        self.image_dim = IMAGE_SIZE # a 28x28 image corresponds to 4 on the FC layer, a 64x64 image corresponds to 13
                            # can calculate this using output_after_conv() in utils.py
        self.latent_dim = 128
        
        self.del1_size = int(IMAGE_SIZE / 32)
        self.del2_size = int(self.image_dim / 16)
        #print(int(self.image_dim / 32))
        #print(self.del1_size)
        self.decoder_fc1 = nn.Sequential(
            nn.Linear(self.latent_dim, 1000),
            nn.Tanh(),
            nn.BatchNorm1d(1000)
        )
        self.decoder_fc2 = nn.Sequential(
            nn.Linear(1000, 512*self.del1_size*self.del1_size),
            nn.Tanh(),
            nn.BatchNorm1d(512*self.del1_size*self.del1_size)
        )
        self.decoder_l1 = nn.Sequential(
            nn.ConvTranspose2d(512, 256, kernel_size=3, stride=2, padding=1, output_padding=1),
            #nn.ConvTranspose2d(512, 512, kernel_size=3, stride=1, padding=1),
            #nn.ConvTranspose2d(512, 256, kernel_size=3, stride=1, padding=1),
            #nn.MaxUnpool2d(3, stride=2),
            nn.ReLU(),
            nn.BatchNorm2d(256)
        )
        #self.m1 = nn.MaxPool2d(3, stride=2)
        self.decoder_l2 = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            #nn.ConvTranspose2d(256, 256, kernel_size=3, stride=1, padding=1),
            #nn.ConvTranspose2d(256, 128, kernel_size=3, stride=1, padding=1),
            #nn.MaxUnpool2d(3, stride=2),
            nn.ReLU(),
            nn.BatchNorm2d(128)
        )
        #self.m1 = nn.MaxPool2d(3, stride=2)
        self.decoder_l3 = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            #nn.ConvTranspose2d(128, 64, kernel_size=3, stride=1, padding=1),
            #nn.MaxUnpool2d(3, stride=2),
            nn.ReLU(),
            nn.BatchNorm2d(64)
        )
        #self.m1 = nn.MaxPool2d(3, stride=2)
        self.decoder_l4 = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32)
            #nn.ConvTranspose2d(64, 3, kernel_size=3, stride=1, padding=1),
            #nn.MaxUnpool2d(3, stride=2)
        )
        self.decoder_l5 = nn.Sequential(
            nn.ConvTranspose2d(32, 3, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Tanh()
        )
        
    def forward(self, z):
        x_hat = self.decoder_fc1(z)
        x_hat = self.decoder_fc2(x_hat)
        x_hat = x_hat.view(-1, 512, self.del1_size, self.del1_size)

        x_hat = self.decoder_l1(x_hat)
        x_hat = self.decoder_l2(x_hat)
        
        x_hat = self.decoder_l3(x_hat)
        
        x_hat = self.decoder_l4(x_hat)
        
        x_hat = self.decoder_l5(x_hat)

        return x_hat
    
class Embdding_128(nn.Module):
    def __init__(self, IMAGE_SIZE):
        super(Embdding_128, self).__init__()

        self.encoder = EmbeddingModel(3)
        self.decoder = Decoder(IMAGE_SIZE)
        
        
    def forward(self, x):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return z, x_hat

    def encode(self, x):
        #x = x.unsqueeze(0)
        z, x_hat = self.forward(x)

        return z

# %%
def deTanh(x):
    return x.add(1).mul(0.5)
def Tanhize(x):
    return x.mul(2).add(-1)

# %%
model = model_emb(IMAGE_SIZE)
if cuda:
    model.cuda()
num_epochs = 10000
model = nn.DataParallel(model)
model.batch_size = BATCH_SIZE
learning_rate = 1e-3
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    for i, (images, masks) in enumerate(cocoloader):
        if cuda:
            x = Tanhize(Variable(images).cuda())
        else:
            x = Tanhize(Variable(images))

        # Forward + Backward + Optimize
        optimizer.zero_grad()
        z, x_hat = model(x)
        #print(x.shape, x_hat.shape)
        loss = criterion(x_hat, x)
        loss.backward()
        optimizer.step()
        if (i + 1) % 30 == 0:
            print('Epoch [%d/%d], Step[%d/%d], d_loss: %.4f, '
                  'g_loss: %.4f, Mean D(x): %.2f, Mean D(G(z)): %.2f' 
                  %(epoch,
                    num_epochs,
                    i + 1,
                    n_batches,
                    loss.data,
                    loss.data,
                    0,
                    0)
            )

    # Save real images once
#     import pdb
#     pdb.set_trace()
    if (epoch + 1) == 1:
        images = images.view(images.size(0), 3, 224, 224) # reshape
        save_image(images.data, './Experiments/3_animals_2_fruit/obj_data/real_images.png')
    fake_images = deTanh(x_hat)
    # Save sampled images
    #import pdb
    #pdb.set_trace()
    #fake_images = fake_images.view(fake_images.size(0), 3, 28, 28) #reshape
    #print(x_hat[0])
    #print(x_hat[0])
    if epoch % 100 == 0:
        save_image(fake_images.data, './Experiments/3_animals_2_fruit/obj_data/fake_images-%0.3d.png' %(epoch + 1))

    # Save the trained parameters 
    if epoch % 1000 == 0:
        torch.save(model.state_dict(), './Experiments/3_animals_2_fruit/obj_weight/weight_' + str(epoch) + '.pkl')
#     torch.save(D.state_dict(), './weights/discriminator-%0.3d.pkl' %(epoch + 1))
# Out:
# Epoch [0/10000], Step[30/69], d_loss: 0.4489, g_loss: 0.4489, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [0/10000], Step[60/69], d_loss: 0.2346, g_loss: 0.2346, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [1/10000], Step[30/69], d_loss: 0.1591, g_loss: 0.1591, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [1/10000], Step[60/69], d_loss: 0.1279, g_loss: 0.1279, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [2/10000], Step[30/69], d_loss: 0.1029, g_loss: 0.1029, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [2/10000], Step[60/69], d_loss: 0.0943, g_loss: 0.0943, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [3/10000], Step[30/69], d_loss: 0.0915, g_loss: 0.0915, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [3/10000], Step[60/69], d_loss: 0.0850, g_loss: 0.0850, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [4/10000], Step[30/69], d_loss: 0.0780, g_loss: 0.0780, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [4/10000], Step[60/69], d_loss: 0.0842, g_loss: 0.0842, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [5/10000], Step[30/69], d_loss: 0.0795, g_loss: 0.0795, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [5/10000], Step[60/69], d_loss: 0.0763, g_loss: 0.0763, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [6/10000], Step[30/69], d_loss: 0.0766, g_loss: 0.0766, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [6/10000], Step[60/69], d_loss: 0.0783, g_loss: 0.0783, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [7/10000], Step[30/69], d_loss: 0.0695, g_loss: 0.0695, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [7/10000], Step[60/69], d_loss: 0.0732, g_loss: 0.0732, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [8/10000], Step[30/69], d_loss: 0.0716, g_loss: 0.0716, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [8/10000], Step[60/69], d_loss: 0.0733, g_loss: 0.0733, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [9/10000], Step[30/69], d_loss: 0.0675, g_loss: 0.0675, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [9/10000], Step[60/69], d_loss: 0.0711, g_loss: 0.0711, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [10/10000], Step[30/69], d_loss: 0.0674, g_loss: 0.0674, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [10/10000], Step[60/69], d_loss: 0.0583, g_loss: 0.0583, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [11/10000], Step[30/69], d_loss: 0.0497, g_loss: 0.0497, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [11/10000], Step[60/69], d_loss: 0.0566, g_loss: 0.0566, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [12/10000], Step[30/69], d_loss: 0.0576, g_loss: 0.0576, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [12/10000], Step[60/69], d_loss: 0.0527, g_loss: 0.0527, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [13/10000], Step[30/69], d_loss: 0.0507, g_loss: 0.0507, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [13/10000], Step[60/69], d_loss: 0.0557, g_loss: 0.0557, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [14/10000], Step[30/69], d_loss: 0.0461, g_loss: 0.0461, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [14/10000], Step[60/69], d_loss: 0.0537, g_loss: 0.0537, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [15/10000], Step[30/69], d_loss: 0.0508, g_loss: 0.0508, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [15/10000], Step[60/69], d_loss: 0.0544, g_loss: 0.0544, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [16/10000], Step[30/69], d_loss: 0.0572, g_loss: 0.0572, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [16/10000], Step[60/69], d_loss: 0.0565, g_loss: 0.0565, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [17/10000], Step[30/69], d_loss: 0.0516, g_loss: 0.0516, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [17/10000], Step[60/69], d_loss: 0.0545, g_loss: 0.0545, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [18/10000], Step[30/69], d_loss: 0.0486, g_loss: 0.0486, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [18/10000], Step[60/69], d_loss: 0.0469, g_loss: 0.0469, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [19/10000], Step[30/69], d_loss: 0.0500, g_loss: 0.0500, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [19/10000], Step[60/69], d_loss: 0.0563, g_loss: 0.0563, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [20/10000], Step[30/69], d_loss: 0.0468, g_loss: 0.0468, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [20/10000], Step[60/69], d_loss: 0.0444, g_loss: 0.0444, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [21/10000], Step[30/69], d_loss: 0.0462, g_loss: 0.0462, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [21/10000], Step[60/69], d_loss: 0.0473, g_loss: 0.0473, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [22/10000], Step[30/69], d_loss: 0.0396, g_loss: 0.0396, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [22/10000], Step[60/69], d_loss: 0.0562, g_loss: 0.0562, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [23/10000], Step[30/69], d_loss: 0.0529, g_loss: 0.0529, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [23/10000], Step[60/69], d_loss: 0.0557, g_loss: 0.0557, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [24/10000], Step[30/69], d_loss: 0.0535, g_loss: 0.0535, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [24/10000], Step[60/69], d_loss: 0.0576, g_loss: 0.0576, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [25/10000], Step[30/69], d_loss: 0.0457, g_loss: 0.0457, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [25/10000], Step[60/69], d_loss: 0.0415, g_loss: 0.0415, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [26/10000], Step[30/69], d_loss: 0.0438, g_loss: 0.0438, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [26/10000], Step[60/69], d_loss: 0.0468, g_loss: 0.0468, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [27/10000], Step[30/69], d_loss: 0.0415, g_loss: 0.0415, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [27/10000], Step[60/69], d_loss: 0.0407, g_loss: 0.0407, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [28/10000], Step[30/69], d_loss: 0.0429, g_loss: 0.0429, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [28/10000], Step[60/69], d_loss: 0.0438, g_loss: 0.0438, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [29/10000], Step[30/69], d_loss: 0.0401, g_loss: 0.0401, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [29/10000], Step[60/69], d_loss: 0.0426, g_loss: 0.0426, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [30/10000], Step[30/69], d_loss: 0.0375, g_loss: 0.0375, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [30/10000], Step[60/69], d_loss: 0.0405, g_loss: 0.0405, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [31/10000], Step[30/69], d_loss: 0.0404, g_loss: 0.0404, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [31/10000], Step[60/69], d_loss: 0.0416, g_loss: 0.0416, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [32/10000], Step[30/69], d_loss: 0.0395, g_loss: 0.0395, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [32/10000], Step[60/69], d_loss: 0.0422, g_loss: 0.0422, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [33/10000], Step[30/69], d_loss: 0.0408, g_loss: 0.0408, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [33/10000], Step[60/69], d_loss: 0.0433, g_loss: 0.0433, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [34/10000], Step[30/69], d_loss: 0.0396, g_loss: 0.0396, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [34/10000], Step[60/69], d_loss: 0.0382, g_loss: 0.0382, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [35/10000], Step[30/69], d_loss: 0.0436, g_loss: 0.0436, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [35/10000], Step[60/69], d_loss: 0.0392, g_loss: 0.0392, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [36/10000], Step[30/69], d_loss: 0.0372, g_loss: 0.0372, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [36/10000], Step[60/69], d_loss: 0.0396, g_loss: 0.0396, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [37/10000], Step[30/69], d_loss: 0.0372, g_loss: 0.0372, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [37/10000], Step[60/69], d_loss: 0.0421, g_loss: 0.0421, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [38/10000], Step[30/69], d_loss: 0.0348, g_loss: 0.0348, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [38/10000], Step[60/69], d_loss: 0.0380, g_loss: 0.0380, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [39/10000], Step[30/69], d_loss: 0.0433, g_loss: 0.0433, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [39/10000], Step[60/69], d_loss: 0.0351, g_loss: 0.0351, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [40/10000], Step[30/69], d_loss: 0.0349, g_loss: 0.0349, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [40/10000], Step[60/69], d_loss: 0.0346, g_loss: 0.0346, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [41/10000], Step[30/69], d_loss: 0.0319, g_loss: 0.0319, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [41/10000], Step[60/69], d_loss: 0.0366, g_loss: 0.0366, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [42/10000], Step[30/69], d_loss: 0.0416, g_loss: 0.0416, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [42/10000], Step[60/69], d_loss: 0.0399, g_loss: 0.0399, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [43/10000], Step[30/69], d_loss: 0.0382, g_loss: 0.0382, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [43/10000], Step[60/69], d_loss: 0.0347, g_loss: 0.0347, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [44/10000], Step[30/69], d_loss: 0.0365, g_loss: 0.0365, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [44/10000], Step[60/69], d_loss: 0.0378, g_loss: 0.0378, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [45/10000], Step[30/69], d_loss: 0.0320, g_loss: 0.0320, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [45/10000], Step[60/69], d_loss: 0.0399, g_loss: 0.0399, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [46/10000], Step[30/69], d_loss: 0.0312, g_loss: 0.0312, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [46/10000], Step[60/69], d_loss: 0.0345, g_loss: 0.0345, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [47/10000], Step[30/69], d_loss: 0.0354, g_loss: 0.0354, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [47/10000], Step[60/69], d_loss: 0.0305, g_loss: 0.0305, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [48/10000], Step[30/69], d_loss: 0.0328, g_loss: 0.0328, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [48/10000], Step[60/69], d_loss: 0.0373, g_loss: 0.0373, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [49/10000], Step[30/69], d_loss: 0.0310, g_loss: 0.0310, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [49/10000], Step[60/69], d_loss: 0.0293, g_loss: 0.0293, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [50/10000], Step[30/69], d_loss: 0.0320, g_loss: 0.0320, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [50/10000], Step[60/69], d_loss: 0.0334, g_loss: 0.0334, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [51/10000], Step[30/69], d_loss: 0.0316, g_loss: 0.0316, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [51/10000], Step[60/69], d_loss: 0.0328, g_loss: 0.0328, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [52/10000], Step[30/69], d_loss: 0.0339, g_loss: 0.0339, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [52/10000], Step[60/69], d_loss: 0.0401, g_loss: 0.0401, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [53/10000], Step[30/69], d_loss: 0.0346, g_loss: 0.0346, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [53/10000], Step[60/69], d_loss: 0.0332, g_loss: 0.0332, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [54/10000], Step[30/69], d_loss: 0.0312, g_loss: 0.0312, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [54/10000], Step[60/69], d_loss: 0.0294, g_loss: 0.0294, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [55/10000], Step[30/69], d_loss: 0.0351, g_loss: 0.0351, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [55/10000], Step[60/69], d_loss: 0.0368, g_loss: 0.0368, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [56/10000], Step[30/69], d_loss: 0.0340, g_loss: 0.0340, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [56/10000], Step[60/69], d_loss: 0.0354, g_loss: 0.0354, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [57/10000], Step[30/69], d_loss: 0.0378, g_loss: 0.0378, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [57/10000], Step[60/69], d_loss: 0.0357, g_loss: 0.0357, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [58/10000], Step[30/69], d_loss: 0.0290, g_loss: 0.0290, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [58/10000], Step[60/69], d_loss: 0.0284, g_loss: 0.0284, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [59/10000], Step[30/69], d_loss: 0.0305, g_loss: 0.0305, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [59/10000], Step[60/69], d_loss: 0.0325, g_loss: 0.0325, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [60/10000], Step[30/69], d_loss: 0.0310, g_loss: 0.0310, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [60/10000], Step[60/69], d_loss: 0.0304, g_loss: 0.0304, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [61/10000], Step[30/69], d_loss: 0.0369, g_loss: 0.0369, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [61/10000], Step[60/69], d_loss: 0.0298, g_loss: 0.0298, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [62/10000], Step[30/69], d_loss: 0.0319, g_loss: 0.0319, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [62/10000], Step[60/69], d_loss: 0.0293, g_loss: 0.0293, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [63/10000], Step[30/69], d_loss: 0.0343, g_loss: 0.0343, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [63/10000], Step[60/69], d_loss: 0.0302, g_loss: 0.0302, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [64/10000], Step[30/69], d_loss: 0.0272, g_loss: 0.0272, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [64/10000], Step[60/69], d_loss: 0.0302, g_loss: 0.0302, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [65/10000], Step[30/69], d_loss: 0.0255, g_loss: 0.0255, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [65/10000], Step[60/69], d_loss: 0.0274, g_loss: 0.0274, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [66/10000], Step[30/69], d_loss: 0.0259, g_loss: 0.0259, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [66/10000], Step[60/69], d_loss: 0.0292, g_loss: 0.0292, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [67/10000], Step[30/69], d_loss: 0.0300, g_loss: 0.0300, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [67/10000], Step[60/69], d_loss: 0.0285, g_loss: 0.0285, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [68/10000], Step[30/69], d_loss: 0.0276, g_loss: 0.0276, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [68/10000], Step[60/69], d_loss: 0.0283, g_loss: 0.0283, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [69/10000], Step[30/69], d_loss: 0.0329, g_loss: 0.0329, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [69/10000], Step[60/69], d_loss: 0.0369, g_loss: 0.0369, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [70/10000], Step[30/69], d_loss: 0.0284, g_loss: 0.0284, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [70/10000], Step[60/69], d_loss: 0.0294, g_loss: 0.0294, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [71/10000], Step[30/69], d_loss: 0.0291, g_loss: 0.0291, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [71/10000], Step[60/69], d_loss: 0.0280, g_loss: 0.0280, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [72/10000], Step[30/69], d_loss: 0.0276, g_loss: 0.0276, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [72/10000], Step[60/69], d_loss: 0.0279, g_loss: 0.0279, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [73/10000], Step[30/69], d_loss: 0.0293, g_loss: 0.0293, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [73/10000], Step[60/69], d_loss: 0.0295, g_loss: 0.0295, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [74/10000], Step[30/69], d_loss: 0.0242, g_loss: 0.0242, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [74/10000], Step[60/69], d_loss: 0.0291, g_loss: 0.0291, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [75/10000], Step[30/69], d_loss: 0.0242, g_loss: 0.0242, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [75/10000], Step[60/69], d_loss: 0.0280, g_loss: 0.0280, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [76/10000], Step[30/69], d_loss: 0.0236, g_loss: 0.0236, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [76/10000], Step[60/69], d_loss: 0.0294, g_loss: 0.0294, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [77/10000], Step[30/69], d_loss: 0.0307, g_loss: 0.0307, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [77/10000], Step[60/69], d_loss: 0.0332, g_loss: 0.0332, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [78/10000], Step[30/69], d_loss: 0.0263, g_loss: 0.0263, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [78/10000], Step[60/69], d_loss: 0.0280, g_loss: 0.0280, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [79/10000], Step[30/69], d_loss: 0.0295, g_loss: 0.0295, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [79/10000], Step[60/69], d_loss: 0.0259, g_loss: 0.0259, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [80/10000], Step[30/69], d_loss: 0.0244, g_loss: 0.0244, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [80/10000], Step[60/69], d_loss: 0.0267, g_loss: 0.0267, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [81/10000], Step[30/69], d_loss: 0.0272, g_loss: 0.0272, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [81/10000], Step[60/69], d_loss: 0.0265, g_loss: 0.0265, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [82/10000], Step[30/69], d_loss: 0.0332, g_loss: 0.0332, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [82/10000], Step[60/69], d_loss: 0.0286, g_loss: 0.0286, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [83/10000], Step[30/69], d_loss: 0.0237, g_loss: 0.0237, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [83/10000], Step[60/69], d_loss: 0.0269, g_loss: 0.0269, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [84/10000], Step[30/69], d_loss: 0.0319, g_loss: 0.0319, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [84/10000], Step[60/69], d_loss: 0.0272, g_loss: 0.0272, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [85/10000], Step[30/69], d_loss: 0.0306, g_loss: 0.0306, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [85/10000], Step[60/69], d_loss: 0.0281, g_loss: 0.0281, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [86/10000], Step[30/69], d_loss: 0.0254, g_loss: 0.0254, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [86/10000], Step[60/69], d_loss: 0.0290, g_loss: 0.0290, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [87/10000], Step[30/69], d_loss: 0.0241, g_loss: 0.0241, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [87/10000], Step[60/69], d_loss: 0.0287, g_loss: 0.0287, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [88/10000], Step[30/69], d_loss: 0.0319, g_loss: 0.0319, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [88/10000], Step[60/69], d_loss: 0.0220, g_loss: 0.0220, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [89/10000], Step[30/69], d_loss: 0.0244, g_loss: 0.0244, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [89/10000], Step[60/69], d_loss: 0.0240, g_loss: 0.0240, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [90/10000], Step[30/69], d_loss: 0.0276, g_loss: 0.0276, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [90/10000], Step[60/69], d_loss: 0.0246, g_loss: 0.0246, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [91/10000], Step[30/69], d_loss: 0.0242, g_loss: 0.0242, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [91/10000], Step[60/69], d_loss: 0.0230, g_loss: 0.0230, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [92/10000], Step[30/69], d_loss: 0.0295, g_loss: 0.0295, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [92/10000], Step[60/69], d_loss: 0.0266, g_loss: 0.0266, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [93/10000], Step[30/69], d_loss: 0.0256, g_loss: 0.0256, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [93/10000], Step[60/69], d_loss: 0.0246, g_loss: 0.0246, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [94/10000], Step[30/69], d_loss: 0.0229, g_loss: 0.0229, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [94/10000], Step[60/69], d_loss: 0.0250, g_loss: 0.0250, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [95/10000], Step[30/69], d_loss: 0.0276, g_loss: 0.0276, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [95/10000], Step[60/69], d_loss: 0.0256, g_loss: 0.0256, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [96/10000], Step[30/69], d_loss: 0.0262, g_loss: 0.0262, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [96/10000], Step[60/69], d_loss: 0.0251, g_loss: 0.0251, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [97/10000], Step[30/69], d_loss: 0.0271, g_loss: 0.0271, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [97/10000], Step[60/69], d_loss: 0.0279, g_loss: 0.0279, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [98/10000], Step[30/69], d_loss: 0.0274, g_loss: 0.0274, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [98/10000], Step[60/69], d_loss: 0.0271, g_loss: 0.0271, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [99/10000], Step[30/69], d_loss: 0.0252, g_loss: 0.0252, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [99/10000], Step[60/69], d_loss: 0.0304, g_loss: 0.0304, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [100/10000], Step[30/69], d_loss: 0.0273, g_loss: 0.0273, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [100/10000], Step[60/69], d_loss: 0.0247, g_loss: 0.0247, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [101/10000], Step[30/69], d_loss: 0.0254, g_loss: 0.0254, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [101/10000], Step[60/69], d_loss: 0.0228, g_loss: 0.0228, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [102/10000], Step[30/69], d_loss: 0.0229, g_loss: 0.0229, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [102/10000], Step[60/69], d_loss: 0.0243, g_loss: 0.0243, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [103/10000], Step[30/69], d_loss: 0.0248, g_loss: 0.0248, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [103/10000], Step[60/69], d_loss: 0.0248, g_loss: 0.0248, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [104/10000], Step[30/69], d_loss: 0.0236, g_loss: 0.0236, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [104/10000], Step[60/69], d_loss: 0.0266, g_loss: 0.0266, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [105/10000], Step[30/69], d_loss: 0.0231, g_loss: 0.0231, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [105/10000], Step[60/69], d_loss: 0.0235, g_loss: 0.0235, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [106/10000], Step[30/69], d_loss: 0.0233, g_loss: 0.0233, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [106/10000], Step[60/69], d_loss: 0.0273, g_loss: 0.0273, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [107/10000], Step[30/69], d_loss: 0.0250, g_loss: 0.0250, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [107/10000], Step[60/69], d_loss: 0.0401, g_loss: 0.0401, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [108/10000], Step[30/69], d_loss: 0.0319, g_loss: 0.0319, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [108/10000], Step[60/69], d_loss: 0.0306, g_loss: 0.0306, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [109/10000], Step[30/69], d_loss: 0.0339, g_loss: 0.0339, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [109/10000], Step[60/69], d_loss: 0.0227, g_loss: 0.0227, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [110/10000], Step[30/69], d_loss: 0.0243, g_loss: 0.0243, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [110/10000], Step[60/69], d_loss: 0.0234, g_loss: 0.0234, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [111/10000], Step[30/69], d_loss: 0.0259, g_loss: 0.0259, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [111/10000], Step[60/69], d_loss: 0.0245, g_loss: 0.0245, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [112/10000], Step[30/69], d_loss: 0.0301, g_loss: 0.0301, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [112/10000], Step[60/69], d_loss: 0.0227, g_loss: 0.0227, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [113/10000], Step[30/69], d_loss: 0.0247, g_loss: 0.0247, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [113/10000], Step[60/69], d_loss: 0.0245, g_loss: 0.0245, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [114/10000], Step[30/69], d_loss: 0.0295, g_loss: 0.0295, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [114/10000], Step[60/69], d_loss: 0.0232, g_loss: 0.0232, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [115/10000], Step[30/69], d_loss: 0.0236, g_loss: 0.0236, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [115/10000], Step[60/69], d_loss: 0.0288, g_loss: 0.0288, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [116/10000], Step[30/69], d_loss: 0.0226, g_loss: 0.0226, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [116/10000], Step[60/69], d_loss: 0.0249, g_loss: 0.0249, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [117/10000], Step[30/69], d_loss: 0.0252, g_loss: 0.0252, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [117/10000], Step[60/69], d_loss: 0.0226, g_loss: 0.0226, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [118/10000], Step[30/69], d_loss: 0.0260, g_loss: 0.0260, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [118/10000], Step[60/69], d_loss: 0.0226, g_loss: 0.0226, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [119/10000], Step[30/69], d_loss: 0.0250, g_loss: 0.0250, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [119/10000], Step[60/69], d_loss: 0.0206, g_loss: 0.0206, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [120/10000], Step[30/69], d_loss: 0.0263, g_loss: 0.0263, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [120/10000], Step[60/69], d_loss: 0.0214, g_loss: 0.0214, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [121/10000], Step[30/69], d_loss: 0.0262, g_loss: 0.0262, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [121/10000], Step[60/69], d_loss: 0.0241, g_loss: 0.0241, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [122/10000], Step[30/69], d_loss: 0.0210, g_loss: 0.0210, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [122/10000], Step[60/69], d_loss: 0.0217, g_loss: 0.0217, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [123/10000], Step[30/69], d_loss: 0.0205, g_loss: 0.0205, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [123/10000], Step[60/69], d_loss: 0.0230, g_loss: 0.0230, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [124/10000], Step[30/69], d_loss: 0.0211, g_loss: 0.0211, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [124/10000], Step[60/69], d_loss: 0.0253, g_loss: 0.0253, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [125/10000], Step[30/69], d_loss: 0.0239, g_loss: 0.0239, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [125/10000], Step[60/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [126/10000], Step[30/69], d_loss: 0.0216, g_loss: 0.0216, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [126/10000], Step[60/69], d_loss: 0.0225, g_loss: 0.0225, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [127/10000], Step[30/69], d_loss: 0.0248, g_loss: 0.0248, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [127/10000], Step[60/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [128/10000], Step[30/69], d_loss: 0.0261, g_loss: 0.0261, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [128/10000], Step[60/69], d_loss: 0.0241, g_loss: 0.0241, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [129/10000], Step[30/69], d_loss: 0.0227, g_loss: 0.0227, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [129/10000], Step[60/69], d_loss: 0.0253, g_loss: 0.0253, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [130/10000], Step[30/69], d_loss: 0.0225, g_loss: 0.0225, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [130/10000], Step[60/69], d_loss: 0.0227, g_loss: 0.0227, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [131/10000], Step[30/69], d_loss: 0.0285, g_loss: 0.0285, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [131/10000], Step[60/69], d_loss: 0.0252, g_loss: 0.0252, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [132/10000], Step[30/69], d_loss: 0.0198, g_loss: 0.0198, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [132/10000], Step[60/69], d_loss: 0.0236, g_loss: 0.0236, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [133/10000], Step[30/69], d_loss: 0.0242, g_loss: 0.0242, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [133/10000], Step[60/69], d_loss: 0.0303, g_loss: 0.0303, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [134/10000], Step[30/69], d_loss: 0.0215, g_loss: 0.0215, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [134/10000], Step[60/69], d_loss: 0.0235, g_loss: 0.0235, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [135/10000], Step[30/69], d_loss: 0.0198, g_loss: 0.0198, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [135/10000], Step[60/69], d_loss: 0.0243, g_loss: 0.0243, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [136/10000], Step[30/69], d_loss: 0.0246, g_loss: 0.0246, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [136/10000], Step[60/69], d_loss: 0.0227, g_loss: 0.0227, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [137/10000], Step[30/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [137/10000], Step[60/69], d_loss: 0.0262, g_loss: 0.0262, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [138/10000], Step[30/69], d_loss: 0.0233, g_loss: 0.0233, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [138/10000], Step[60/69], d_loss: 0.0222, g_loss: 0.0222, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [139/10000], Step[30/69], d_loss: 0.0245, g_loss: 0.0245, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [139/10000], Step[60/69], d_loss: 0.0237, g_loss: 0.0237, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [140/10000], Step[30/69], d_loss: 0.0202, g_loss: 0.0202, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [140/10000], Step[60/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [141/10000], Step[30/69], d_loss: 0.0206, g_loss: 0.0206, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [141/10000], Step[60/69], d_loss: 0.0202, g_loss: 0.0202, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [142/10000], Step[30/69], d_loss: 0.0249, g_loss: 0.0249, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [142/10000], Step[60/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [143/10000], Step[30/69], d_loss: 0.0233, g_loss: 0.0233, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [143/10000], Step[60/69], d_loss: 0.0233, g_loss: 0.0233, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [144/10000], Step[30/69], d_loss: 0.0192, g_loss: 0.0192, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [144/10000], Step[60/69], d_loss: 0.0227, g_loss: 0.0227, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [145/10000], Step[30/69], d_loss: 0.0207, g_loss: 0.0207, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [145/10000], Step[60/69], d_loss: 0.0212, g_loss: 0.0212, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [146/10000], Step[30/69], d_loss: 0.0226, g_loss: 0.0226, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [146/10000], Step[60/69], d_loss: 0.0222, g_loss: 0.0222, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [147/10000], Step[30/69], d_loss: 0.0221, g_loss: 0.0221, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [147/10000], Step[60/69], d_loss: 0.0226, g_loss: 0.0226, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [148/10000], Step[30/69], d_loss: 0.0252, g_loss: 0.0252, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [148/10000], Step[60/69], d_loss: 0.0207, g_loss: 0.0207, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [149/10000], Step[30/69], d_loss: 0.0196, g_loss: 0.0196, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [149/10000], Step[60/69], d_loss: 0.0231, g_loss: 0.0231, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [150/10000], Step[30/69], d_loss: 0.0231, g_loss: 0.0231, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [150/10000], Step[60/69], d_loss: 0.0242, g_loss: 0.0242, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [151/10000], Step[30/69], d_loss: 0.0235, g_loss: 0.0235, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [151/10000], Step[60/69], d_loss: 0.0212, g_loss: 0.0212, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [152/10000], Step[30/69], d_loss: 0.0275, g_loss: 0.0275, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [152/10000], Step[60/69], d_loss: 0.0231, g_loss: 0.0231, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [153/10000], Step[30/69], d_loss: 0.0254, g_loss: 0.0254, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [153/10000], Step[60/69], d_loss: 0.0229, g_loss: 0.0229, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [154/10000], Step[30/69], d_loss: 0.0253, g_loss: 0.0253, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [154/10000], Step[60/69], d_loss: 0.0232, g_loss: 0.0232, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [155/10000], Step[30/69], d_loss: 0.0203, g_loss: 0.0203, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [155/10000], Step[60/69], d_loss: 0.0245, g_loss: 0.0245, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [156/10000], Step[30/69], d_loss: 0.0187, g_loss: 0.0187, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [156/10000], Step[60/69], d_loss: 0.0216, g_loss: 0.0216, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [157/10000], Step[30/69], d_loss: 0.0219, g_loss: 0.0219, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [157/10000], Step[60/69], d_loss: 0.0212, g_loss: 0.0212, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [158/10000], Step[30/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [158/10000], Step[60/69], d_loss: 0.0212, g_loss: 0.0212, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [159/10000], Step[30/69], d_loss: 0.0225, g_loss: 0.0225, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [159/10000], Step[60/69], d_loss: 0.0214, g_loss: 0.0214, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [160/10000], Step[30/69], d_loss: 0.0231, g_loss: 0.0231, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [160/10000], Step[60/69], d_loss: 0.0319, g_loss: 0.0319, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [161/10000], Step[30/69], d_loss: 0.0208, g_loss: 0.0208, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [161/10000], Step[60/69], d_loss: 0.0234, g_loss: 0.0234, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [162/10000], Step[30/69], d_loss: 0.0241, g_loss: 0.0241, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [162/10000], Step[60/69], d_loss: 0.0196, g_loss: 0.0196, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [163/10000], Step[30/69], d_loss: 0.0234, g_loss: 0.0234, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [163/10000], Step[60/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [164/10000], Step[30/69], d_loss: 0.0216, g_loss: 0.0216, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [164/10000], Step[60/69], d_loss: 0.0205, g_loss: 0.0205, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [165/10000], Step[30/69], d_loss: 0.0176, g_loss: 0.0176, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [165/10000], Step[60/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [166/10000], Step[30/69], d_loss: 0.0206, g_loss: 0.0206, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [166/10000], Step[60/69], d_loss: 0.0192, g_loss: 0.0192, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [167/10000], Step[30/69], d_loss: 0.0202, g_loss: 0.0202, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [167/10000], Step[60/69], d_loss: 0.0190, g_loss: 0.0190, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [168/10000], Step[30/69], d_loss: 0.0208, g_loss: 0.0208, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [168/10000], Step[60/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [169/10000], Step[30/69], d_loss: 0.0208, g_loss: 0.0208, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [169/10000], Step[60/69], d_loss: 0.0219, g_loss: 0.0219, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [170/10000], Step[30/69], d_loss: 0.0184, g_loss: 0.0184, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [170/10000], Step[60/69], d_loss: 0.0185, g_loss: 0.0185, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [171/10000], Step[30/69], d_loss: 0.0209, g_loss: 0.0209, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [171/10000], Step[60/69], d_loss: 0.0195, g_loss: 0.0195, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [172/10000], Step[30/69], d_loss: 0.0187, g_loss: 0.0187, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [172/10000], Step[60/69], d_loss: 0.0231, g_loss: 0.0231, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [173/10000], Step[30/69], d_loss: 0.0215, g_loss: 0.0215, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [173/10000], Step[60/69], d_loss: 0.0262, g_loss: 0.0262, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [174/10000], Step[30/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [174/10000], Step[60/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [175/10000], Step[30/69], d_loss: 0.0209, g_loss: 0.0209, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [175/10000], Step[60/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [176/10000], Step[30/69], d_loss: 0.0209, g_loss: 0.0209, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [176/10000], Step[60/69], d_loss: 0.0188, g_loss: 0.0188, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [177/10000], Step[30/69], d_loss: 0.0196, g_loss: 0.0196, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [177/10000], Step[60/69], d_loss: 0.0193, g_loss: 0.0193, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [178/10000], Step[30/69], d_loss: 0.0176, g_loss: 0.0176, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [178/10000], Step[60/69], d_loss: 0.0226, g_loss: 0.0226, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [179/10000], Step[30/69], d_loss: 0.0214, g_loss: 0.0214, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [179/10000], Step[60/69], d_loss: 0.0198, g_loss: 0.0198, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [180/10000], Step[30/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [180/10000], Step[60/69], d_loss: 0.0203, g_loss: 0.0203, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [181/10000], Step[30/69], d_loss: 0.0224, g_loss: 0.0224, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [181/10000], Step[60/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [182/10000], Step[30/69], d_loss: 0.0209, g_loss: 0.0209, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [182/10000], Step[60/69], d_loss: 0.0184, g_loss: 0.0184, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [183/10000], Step[30/69], d_loss: 0.0235, g_loss: 0.0235, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [183/10000], Step[60/69], d_loss: 0.0206, g_loss: 0.0206, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [184/10000], Step[30/69], d_loss: 0.0256, g_loss: 0.0256, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [184/10000], Step[60/69], d_loss: 0.0200, g_loss: 0.0200, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [185/10000], Step[30/69], d_loss: 0.0268, g_loss: 0.0268, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [185/10000], Step[60/69], d_loss: 0.0241, g_loss: 0.0241, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [186/10000], Step[30/69], d_loss: 0.0214, g_loss: 0.0214, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [186/10000], Step[60/69], d_loss: 0.0194, g_loss: 0.0194, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [187/10000], Step[30/69], d_loss: 0.0203, g_loss: 0.0203, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [187/10000], Step[60/69], d_loss: 0.0268, g_loss: 0.0268, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [188/10000], Step[30/69], d_loss: 0.0196, g_loss: 0.0196, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [188/10000], Step[60/69], d_loss: 0.0208, g_loss: 0.0208, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [189/10000], Step[30/69], d_loss: 0.0208, g_loss: 0.0208, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [189/10000], Step[60/69], d_loss: 0.0219, g_loss: 0.0219, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [190/10000], Step[30/69], d_loss: 0.0182, g_loss: 0.0182, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [190/10000], Step[60/69], d_loss: 0.0219, g_loss: 0.0219, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [191/10000], Step[30/69], d_loss: 0.0203, g_loss: 0.0203, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [191/10000], Step[60/69], d_loss: 0.0166, g_loss: 0.0166, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [192/10000], Step[30/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [192/10000], Step[60/69], d_loss: 0.0180, g_loss: 0.0180, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [193/10000], Step[30/69], d_loss: 0.0230, g_loss: 0.0230, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [193/10000], Step[60/69], d_loss: 0.0210, g_loss: 0.0210, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [194/10000], Step[30/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [194/10000], Step[60/69], d_loss: 0.0190, g_loss: 0.0190, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [195/10000], Step[30/69], d_loss: 0.0241, g_loss: 0.0241, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [195/10000], Step[60/69], d_loss: 0.0209, g_loss: 0.0209, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [196/10000], Step[30/69], d_loss: 0.0235, g_loss: 0.0235, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [196/10000], Step[60/69], d_loss: 0.0199, g_loss: 0.0199, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [197/10000], Step[30/69], d_loss: 0.0199, g_loss: 0.0199, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [197/10000], Step[60/69], d_loss: 0.0200, g_loss: 0.0200, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [198/10000], Step[30/69], d_loss: 0.0224, g_loss: 0.0224, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [198/10000], Step[60/69], d_loss: 0.0183, g_loss: 0.0183, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [199/10000], Step[30/69], d_loss: 0.0192, g_loss: 0.0192, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [199/10000], Step[60/69], d_loss: 0.0204, g_loss: 0.0204, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [200/10000], Step[30/69], d_loss: 0.0213, g_loss: 0.0213, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [200/10000], Step[60/69], d_loss: 0.0232, g_loss: 0.0232, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [201/10000], Step[30/69], d_loss: 0.0205, g_loss: 0.0205, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [201/10000], Step[60/69], d_loss: 0.0188, g_loss: 0.0188, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [202/10000], Step[30/69], d_loss: 0.0214, g_loss: 0.0214, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [202/10000], Step[60/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [203/10000], Step[30/69], d_loss: 0.0248, g_loss: 0.0248, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [203/10000], Step[60/69], d_loss: 0.0192, g_loss: 0.0192, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [204/10000], Step[30/69], d_loss: 0.0206, g_loss: 0.0206, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [204/10000], Step[60/69], d_loss: 0.0221, g_loss: 0.0221, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [205/10000], Step[30/69], d_loss: 0.0190, g_loss: 0.0190, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [205/10000], Step[60/69], d_loss: 0.0189, g_loss: 0.0189, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [206/10000], Step[30/69], d_loss: 0.0175, g_loss: 0.0175, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [206/10000], Step[60/69], d_loss: 0.0172, g_loss: 0.0172, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [207/10000], Step[30/69], d_loss: 0.0187, g_loss: 0.0187, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [207/10000], Step[60/69], d_loss: 0.0167, g_loss: 0.0167, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [208/10000], Step[30/69], d_loss: 0.0206, g_loss: 0.0206, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [208/10000], Step[60/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [209/10000], Step[30/69], d_loss: 0.0221, g_loss: 0.0221, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [209/10000], Step[60/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [210/10000], Step[30/69], d_loss: 0.0177, g_loss: 0.0177, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [210/10000], Step[60/69], d_loss: 0.0216, g_loss: 0.0216, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [211/10000], Step[30/69], d_loss: 0.0198, g_loss: 0.0198, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [211/10000], Step[60/69], d_loss: 0.0168, g_loss: 0.0168, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [212/10000], Step[30/69], d_loss: 0.0214, g_loss: 0.0214, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [212/10000], Step[60/69], d_loss: 0.0223, g_loss: 0.0223, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [213/10000], Step[30/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [213/10000], Step[60/69], d_loss: 0.0192, g_loss: 0.0192, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [214/10000], Step[30/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [214/10000], Step[60/69], d_loss: 0.0202, g_loss: 0.0202, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [215/10000], Step[30/69], d_loss: 0.0183, g_loss: 0.0183, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [215/10000], Step[60/69], d_loss: 0.0209, g_loss: 0.0209, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [216/10000], Step[30/69], d_loss: 0.0195, g_loss: 0.0195, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [216/10000], Step[60/69], d_loss: 0.0174, g_loss: 0.0174, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [217/10000], Step[30/69], d_loss: 0.0175, g_loss: 0.0175, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [217/10000], Step[60/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [218/10000], Step[30/69], d_loss: 0.0225, g_loss: 0.0225, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [218/10000], Step[60/69], d_loss: 0.0183, g_loss: 0.0183, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [219/10000], Step[30/69], d_loss: 0.0195, g_loss: 0.0195, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [219/10000], Step[60/69], d_loss: 0.0213, g_loss: 0.0213, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [220/10000], Step[30/69], d_loss: 0.0175, g_loss: 0.0175, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [220/10000], Step[60/69], d_loss: 0.0193, g_loss: 0.0193, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [221/10000], Step[30/69], d_loss: 0.0211, g_loss: 0.0211, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [221/10000], Step[60/69], d_loss: 0.0225, g_loss: 0.0225, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [222/10000], Step[30/69], d_loss: 0.0182, g_loss: 0.0182, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [222/10000], Step[60/69], d_loss: 0.0162, g_loss: 0.0162, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [223/10000], Step[30/69], d_loss: 0.0176, g_loss: 0.0176, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [223/10000], Step[60/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [224/10000], Step[30/69], d_loss: 0.0187, g_loss: 0.0187, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [224/10000], Step[60/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [225/10000], Step[30/69], d_loss: 0.0174, g_loss: 0.0174, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [225/10000], Step[60/69], d_loss: 0.0180, g_loss: 0.0180, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [226/10000], Step[30/69], d_loss: 0.0194, g_loss: 0.0194, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [226/10000], Step[60/69], d_loss: 0.0188, g_loss: 0.0188, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [227/10000], Step[30/69], d_loss: 0.0182, g_loss: 0.0182, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [227/10000], Step[60/69], d_loss: 0.0225, g_loss: 0.0225, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [228/10000], Step[30/69], d_loss: 0.0321, g_loss: 0.0321, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [228/10000], Step[60/69], d_loss: 0.0267, g_loss: 0.0267, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [229/10000], Step[30/69], d_loss: 0.0204, g_loss: 0.0204, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [229/10000], Step[60/69], d_loss: 0.0207, g_loss: 0.0207, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [230/10000], Step[30/69], d_loss: 0.0200, g_loss: 0.0200, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [230/10000], Step[60/69], d_loss: 0.0211, g_loss: 0.0211, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [231/10000], Step[30/69], d_loss: 0.0207, g_loss: 0.0207, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [231/10000], Step[60/69], d_loss: 0.0170, g_loss: 0.0170, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [232/10000], Step[30/69], d_loss: 0.0218, g_loss: 0.0218, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [232/10000], Step[60/69], d_loss: 0.0205, g_loss: 0.0205, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [233/10000], Step[30/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [233/10000], Step[60/69], d_loss: 0.0161, g_loss: 0.0161, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [234/10000], Step[30/69], d_loss: 0.0188, g_loss: 0.0188, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [234/10000], Step[60/69], d_loss: 0.0176, g_loss: 0.0176, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [235/10000], Step[30/69], d_loss: 0.0189, g_loss: 0.0189, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [235/10000], Step[60/69], d_loss: 0.0238, g_loss: 0.0238, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [236/10000], Step[30/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [236/10000], Step[60/69], d_loss: 0.0196, g_loss: 0.0196, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [237/10000], Step[30/69], d_loss: 0.0180, g_loss: 0.0180, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [237/10000], Step[60/69], d_loss: 0.0175, g_loss: 0.0175, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [238/10000], Step[30/69], d_loss: 0.0221, g_loss: 0.0221, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [238/10000], Step[60/69], d_loss: 0.0159, g_loss: 0.0159, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [239/10000], Step[30/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [239/10000], Step[60/69], d_loss: 0.0191, g_loss: 0.0191, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [240/10000], Step[30/69], d_loss: 0.0167, g_loss: 0.0167, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [240/10000], Step[60/69], d_loss: 0.0212, g_loss: 0.0212, Mean D(x): 0.00, Mean D(G(z)): 0.00
# ...
# Epoch [260/10000], Step[30/69], d_loss: 0.0194, g_loss: 0.0194, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [260/10000], Step[60/69], d_loss: 0.0176, g_loss: 0.0176, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [261/10000], Step[30/69], d_loss: 0.0214, g_loss: 0.0214, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [261/10000], Step[60/69], d_loss: 0.0168, g_loss: 0.0168, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [262/10000], Step[30/69], d_loss: 0.0171, g_loss: 0.0171, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [262/10000], Step[60/69], d_loss: 0.0162, g_loss: 0.0162, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [263/10000], Step[30/69], d_loss: 0.0163, g_loss: 0.0163, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [263/10000], Step[60/69], d_loss: 0.0165, g_loss: 0.0165, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [264/10000], Step[30/69], d_loss: 0.0144, g_loss: 0.0144, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [264/10000], Step[60/69], d_loss: 0.0185, g_loss: 0.0185, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [265/10000], Step[30/69], d_loss: 0.0178, g_loss: 0.0178, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [265/10000], Step[60/69], d_loss: 0.0219, g_loss: 0.0219, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [266/10000], Step[30/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [266/10000], Step[60/69], d_loss: 0.0164, g_loss: 0.0164, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [267/10000], Step[30/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [267/10000], Step[60/69], d_loss: 0.0157, g_loss: 0.0157, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [268/10000], Step[30/69], d_loss: 0.0172, g_loss: 0.0172, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [268/10000], Step[60/69], d_loss: 0.0190, g_loss: 0.0190, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [269/10000], Step[30/69], d_loss: 0.0190, g_loss: 0.0190, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [269/10000], Step[60/69], d_loss: 0.0199, g_loss: 0.0199, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [270/10000], Step[30/69], d_loss: 0.0190, g_loss: 0.0190, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [270/10000], Step[60/69], d_loss: 0.0172, g_loss: 0.0172, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [271/10000], Step[30/69], d_loss: 0.0195, g_loss: 0.0195, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [271/10000], Step[60/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [272/10000], Step[30/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [272/10000], Step[60/69], d_loss: 0.0176, g_loss: 0.0176, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [273/10000], Step[30/69], d_loss: 0.0172, g_loss: 0.0172, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [273/10000], Step[60/69], d_loss: 0.0195, g_loss: 0.0195, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [274/10000], Step[30/69], d_loss: 0.0197, g_loss: 0.0197, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [274/10000], Step[60/69], d_loss: 0.0198, g_loss: 0.0198, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [275/10000], Step[30/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [275/10000], Step[60/69], d_loss: 0.0147, g_loss: 0.0147, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [276/10000], Step[30/69], d_loss: 0.0179, g_loss: 0.0179, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [276/10000], Step[60/69], d_loss: 0.0182, g_loss: 0.0182, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [277/10000], Step[30/69], d_loss: 0.0175, g_loss: 0.0175, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [277/10000], Step[60/69], d_loss: 0.0153, g_loss: 0.0153, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [278/10000], Step[30/69], d_loss: 0.0177, g_loss: 0.0177, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [278/10000], Step[60/69], d_loss: 0.0183, g_loss: 0.0183, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [279/10000], Step[30/69], d_loss: 0.0165, g_loss: 0.0165, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [279/10000], Step[60/69], d_loss: 0.0199, g_loss: 0.0199, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [280/10000], Step[30/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [280/10000], Step[60/69], d_loss: 0.0186, g_loss: 0.0186, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [281/10000], Step[30/69], d_loss: 0.0160, g_loss: 0.0160, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [281/10000], Step[60/69], d_loss: 0.0171, g_loss: 0.0171, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [282/10000], Step[30/69], d_loss: 0.0192, g_loss: 0.0192, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [282/10000], Step[60/69], d_loss: 0.0158, g_loss: 0.0158, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [283/10000], Step[30/69], d_loss: 0.0163, g_loss: 0.0163, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [283/10000], Step[60/69], d_loss: 0.0203, g_loss: 0.0203, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [284/10000], Step[30/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [284/10000], Step[60/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [285/10000], Step[30/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [285/10000], Step[60/69], d_loss: 0.0147, g_loss: 0.0147, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [286/10000], Step[30/69], d_loss: 0.0176, g_loss: 0.0176, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [286/10000], Step[60/69], d_loss: 0.0187, g_loss: 0.0187, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [287/10000], Step[30/69], d_loss: 0.0183, g_loss: 0.0183, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [287/10000], Step[60/69], d_loss: 0.0184, g_loss: 0.0184, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [288/10000], Step[30/69], d_loss: 0.0162, g_loss: 0.0162, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [288/10000], Step[60/69], d_loss: 0.0151, g_loss: 0.0151, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [289/10000], Step[30/69], d_loss: 0.0160, g_loss: 0.0160, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [289/10000], Step[60/69], d_loss: 0.0155, g_loss: 0.0155, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [290/10000], Step[30/69], d_loss: 0.0184, g_loss: 0.0184, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [290/10000], Step[60/69], d_loss: 0.0159, g_loss: 0.0159, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [291/10000], Step[30/69], d_loss: 0.0249, g_loss: 0.0249, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [291/10000], Step[60/69], d_loss: 0.0155, g_loss: 0.0155, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [292/10000], Step[30/69], d_loss: 0.0199, g_loss: 0.0199, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [292/10000], Step[60/69], d_loss: 0.0149, g_loss: 0.0149, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [293/10000], Step[30/69], d_loss: 0.0177, g_loss: 0.0177, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [293/10000], Step[60/69], d_loss: 0.0181, g_loss: 0.0181, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [294/10000], Step[30/69], d_loss: 0.0154, g_loss: 0.0154, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [294/10000], Step[60/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [295/10000], Step[30/69], d_loss: 0.0206, g_loss: 0.0206, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [295/10000], Step[60/69], d_loss: 0.0155, g_loss: 0.0155, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [296/10000], Step[30/69], d_loss: 0.0167, g_loss: 0.0167, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [296/10000], Step[60/69], d_loss: 0.0166, g_loss: 0.0166, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [297/10000], Step[30/69], d_loss: 0.0154, g_loss: 0.0154, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [297/10000], Step[60/69], d_loss: 0.0153, g_loss: 0.0153, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [298/10000], Step[30/69], d_loss: 0.0174, g_loss: 0.0174, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [298/10000], Step[60/69], d_loss: 0.0174, g_loss: 0.0174, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [299/10000], Step[30/69], d_loss: 0.0145, g_loss: 0.0145, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [299/10000], Step[60/69], d_loss: 0.0155, g_loss: 0.0155, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [300/10000], Step[30/69], d_loss: 0.0190, g_loss: 0.0190, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [300/10000], Step[60/69], d_loss: 0.0159, g_loss: 0.0159, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [301/10000], Step[30/69], d_loss: 0.0157, g_loss: 0.0157, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [301/10000], Step[60/69], d_loss: 0.0166, g_loss: 0.0166, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [302/10000], Step[30/69], d_loss: 0.0142, g_loss: 0.0142, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [302/10000], Step[60/69], d_loss: 0.0155, g_loss: 0.0155, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [303/10000], Step[30/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [303/10000], Step[60/69], d_loss: 0.0188, g_loss: 0.0188, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [304/10000], Step[30/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [304/10000], Step[60/69], d_loss: 0.0165, g_loss: 0.0165, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [305/10000], Step[30/69], d_loss: 0.0188, g_loss: 0.0188, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [305/10000], Step[60/69], d_loss: 0.0152, g_loss: 0.0152, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [306/10000], Step[30/69], d_loss: 0.0161, g_loss: 0.0161, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [306/10000], Step[60/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [307/10000], Step[30/69], d_loss: 0.0185, g_loss: 0.0185, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [307/10000], Step[60/69], d_loss: 0.0138, g_loss: 0.0138, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [308/10000], Step[30/69], d_loss: 0.0183, g_loss: 0.0183, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [308/10000], Step[60/69], d_loss: 0.0159, g_loss: 0.0159, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [309/10000], Step[30/69], d_loss: 0.0150, g_loss: 0.0150, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [309/10000], Step[60/69], d_loss: 0.0164, g_loss: 0.0164, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [310/10000], Step[30/69], d_loss: 0.0170, g_loss: 0.0170, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [310/10000], Step[60/69], d_loss: 0.0170, g_loss: 0.0170, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [311/10000], Step[30/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [311/10000], Step[60/69], d_loss: 0.0141, g_loss: 0.0141, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [312/10000], Step[30/69], d_loss: 0.0154, g_loss: 0.0154, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [312/10000], Step[60/69], d_loss: 0.0153, g_loss: 0.0153, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [313/10000], Step[30/69], d_loss: 0.0166, g_loss: 0.0166, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [313/10000], Step[60/69], d_loss: 0.0193, g_loss: 0.0193, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [314/10000], Step[30/69], d_loss: 0.0161, g_loss: 0.0161, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [314/10000], Step[60/69], d_loss: 0.0174, g_loss: 0.0174, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [315/10000], Step[30/69], d_loss: 0.0159, g_loss: 0.0159, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [315/10000], Step[60/69], d_loss: 0.0178, g_loss: 0.0178, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [316/10000], Step[30/69], d_loss: 0.0149, g_loss: 0.0149, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [316/10000], Step[60/69], d_loss: 0.0158, g_loss: 0.0158, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [317/10000], Step[30/69], d_loss: 0.0143, g_loss: 0.0143, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [317/10000], Step[60/69], d_loss: 0.0152, g_loss: 0.0152, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [318/10000], Step[30/69], d_loss: 0.0148, g_loss: 0.0148, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [318/10000], Step[60/69], d_loss: 0.0164, g_loss: 0.0164, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [319/10000], Step[30/69], d_loss: 0.0173, g_loss: 0.0173, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [319/10000], Step[60/69], d_loss: 0.0174, g_loss: 0.0174, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [320/10000], Step[30/69], d_loss: 0.0175, g_loss: 0.0175, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [320/10000], Step[60/69], d_loss: 0.0163, g_loss: 0.0163, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [321/10000], Step[30/69], d_loss: 0.0179, g_loss: 0.0179, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [321/10000], Step[60/69], d_loss: 0.0138, g_loss: 0.0138, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [322/10000], Step[30/69], d_loss: 0.0165, g_loss: 0.0165, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [322/10000], Step[60/69], d_loss: 0.0149, g_loss: 0.0149, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [323/10000], Step[30/69], d_loss: 0.0168, g_loss: 0.0168, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [323/10000], Step[60/69], d_loss: 0.0158, g_loss: 0.0158, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [324/10000], Step[30/69], d_loss: 0.0184, g_loss: 0.0184, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [324/10000], Step[60/69], d_loss: 0.0146, g_loss: 0.0146, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [325/10000], Step[30/69], d_loss: 0.0145, g_loss: 0.0145, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [325/10000], Step[60/69], d_loss: 0.0157, g_loss: 0.0157, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [326/10000], Step[30/69], d_loss: 0.0177, g_loss: 0.0177, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [326/10000], Step[60/69], d_loss: 0.0180, g_loss: 0.0180, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [327/10000], Step[30/69], d_loss: 0.0152, g_loss: 0.0152, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [327/10000], Step[60/69], d_loss: 0.0152, g_loss: 0.0152, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [328/10000], Step[30/69], d_loss: 0.0171, g_loss: 0.0171, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [328/10000], Step[60/69], d_loss: 0.0179, g_loss: 0.0179, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [329/10000], Step[30/69], d_loss: 0.0155, g_loss: 0.0155, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [329/10000], Step[60/69], d_loss: 0.0148, g_loss: 0.0148, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [330/10000], Step[30/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [330/10000], Step[60/69], d_loss: 0.0146, g_loss: 0.0146, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [331/10000], Step[30/69], d_loss: 0.0148, g_loss: 0.0148, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [331/10000], Step[60/69], d_loss: 0.0128, g_loss: 0.0128, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [332/10000], Step[30/69], d_loss: 0.0166, g_loss: 0.0166, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [332/10000], Step[60/69], d_loss: 0.0150, g_loss: 0.0150, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [333/10000], Step[30/69], d_loss: 0.0138, g_loss: 0.0138, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [333/10000], Step[60/69], d_loss: 0.0153, g_loss: 0.0153, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [334/10000], Step[30/69], d_loss: 0.0140, g_loss: 0.0140, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [334/10000], Step[60/69], d_loss: 0.0152, g_loss: 0.0152, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [335/10000], Step[30/69], d_loss: 0.0157, g_loss: 0.0157, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [335/10000], Step[60/69], d_loss: 0.0151, g_loss: 0.0151, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [336/10000], Step[30/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [336/10000], Step[60/69], d_loss: 0.0169, g_loss: 0.0169, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [337/10000], Step[30/69], d_loss: 0.0144, g_loss: 0.0144, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [337/10000], Step[60/69], d_loss: 0.0158, g_loss: 0.0158, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [338/10000], Step[30/69], d_loss: 0.0160, g_loss: 0.0160, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [338/10000], Step[60/69], d_loss: 0.0148, g_loss: 0.0148, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [339/10000], Step[30/69], d_loss: 0.0143, g_loss: 0.0143, Mean D(x): 0.00, Mean D(G(z)): 0.00
# Epoch [339/10000], Step[60/69], d_loss: 0.0155, g_loss: 0.0155, Mean D(x): 0.00, Mean D(G(z)): 0.00
